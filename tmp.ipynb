# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import thinkbayes2

# %%
pa = PollAggregator()
pa.update(0.2, 'A', 500, 0)
pa.display()

# %%
pa.update(0.25, 'B', 10000, 0)
pa.display()
